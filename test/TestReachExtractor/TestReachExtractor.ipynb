# %%
from SWOTRiver import SWOTL2
from SWOTRiver import ReachExtractor

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_dir = '/Volumes/Reservoir/Data/SWOT/'
l2_file = (data_dir +
    'swot_intf_line1_cycle_0001_pass_0277_w0.23_15dB_slp0.1deg.LeftSwath.nc')

db_dir = '../../data/nAmerica_GRWDL_river_topo/'
shape_file_root = db_dir+'nAmerica_GRWDL_river_topo'

# %%
l2 = SWOTL2(l2_file)
# Out:
# Dataset opened
# Bounding box calculated
# Good data selected
# lat/lon read
# projection set and x,y calculated

# %%
reaches = ReachExtractor(shape_file_root, l2,clip_buffer=0)

# %%
reaches[0].metadata
# Out:
# {'break_idx': 1388940,
#  'latmax': 40.03200149536133,
#  'latmin': 38.16350173950195,
#  'lonmax': -121.5009994506836,
#  'lonmin': -122.11900329589844,
#  'npoints': 10144,
#  'reach': 375745.03125,
#  'width_max': 532.0,
#  'width_mean': 115.74655151367188,
#  'width_min': 30.0,
#  'width_std': 52.802425384521484}

# %%
figsize(6,6)
scatter(l2.lon,l2.lat,edgecolor='none',alpha=0.1)
for reach in reaches:
    lon, lat = reach.lon, reach.lat
    plot(lon,lat,'.m',alpha=0.1)

# %%
figsize(6,6)
scatter(l2.x/1.e3,l2.y/1.e3,edgecolor='none',alpha=0.1)
for reach in reaches:
    x, y = reach.x, reach.y
    plot(x/1.e3,y/1.e3,'.m',alpha=0.1)

# %%
reaches[0:-1]
# Out:
# [<SWOTRiver.ReachExtractor.RiverReach instance at 0x101fd6cb0>]

# %%
reaches[:]
# Out:
# [<SWOTRiver.ReachExtractor.RiverReach instance at 0x101fd6cb0>,
#  <SWOTRiver.ReachExtractor.RiverReach instance at 0x10d0c3950>]

# %%
len(reaches)
# Out:
# 2

# %%
reaches.reach_idx
# Out:
# [704, 705]

# %%
len(reach.lon)
# Out:
# 125
